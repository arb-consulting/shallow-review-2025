# %%
import openai
import os
import pandas as pd

openai.api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Step 1: Get summaries and tags for each post

# %% [markdown]
# The first step is to upload a CSV with two columns named "link" and "title".

# %%
df = pd.read_csv("output/alignment-forum-top-100.csv")
df.head()
# Out:
#                                                title  \
# 0    Video lectures on the learning-theoretic agenda
# 1                A bird's eye view of ARC's research
# 2  Circuits in Superposition: Compressing many sm...
# 3  [Paper Blogpost] When Your AIs Deceive You: Ch...
# 4  The case for unlearning that removes informati...
#
#                                                 link read
# 0  https://www.alignmentforum.org/posts/NWKk2eQwf...  NaN
# 1  https://www.alignmentforum.org/posts/ztokaf9ha...  NaN
# 2  https://www.alignmentforum.org/posts/roE7SHjFW...  NaN
# 3  https://www.alignmentforum.org/posts/DS3TTpCEF...  NaN
# 4  https://www.alignmentforum.org/posts/9AbYkAy8s...  NaN

# %% [markdown]
# Convert the date column to a datetime object and then to a formatted date.

# %%
df['date'] = pd.to_datetime(df['date'])
df['date'] = df['date'].dt.strftime('%Y-%m-%d')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df['date'] = pd.to_datetime(df['date'])
#       2 df['date'] = df['date'].dt.strftime('%Y-%m-%d')
#       3 df.head()
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'date'

# %%
print(f'Processing {df.shape[0]} rows')
df.head()
# Out:
# Processing 99 rows
#                                                title  \
# 0    Video lectures on the learning-theoretic agenda
# 1                A bird's eye view of ARC's research
# 2  Circuits in Superposition: Compressing many sm...
# 3  [Paper Blogpost] When Your AIs Deceive You: Ch...
# 4  The case for unlearning that removes informati...
#
#                                                 link
# 0  https://www.alignmentforum.org/posts/NWKk2eQwf...
# 1  https://www.alignmentforum.org/posts/ztokaf9ha...
# 2  https://www.alignmentforum.org/posts/roE7SHjFW...
# 3  https://www.alignmentforum.org/posts/DS3TTpCEF...
# 4  https://www.alignmentforum.org/posts/9AbYkAy8s...

# %% [markdown]
# Then use Python to open each link and get the text. Give the text to an LLM and ask it write a summary.
#
# For each link, create a summary and add it to a new column called "summary".

# %%
summary_prompt = """
You are an academic research and your task is to help write a literature review of the field of AI alignment.

Your current task is to read a blog post from the AI Alignment Forum and summarize it in 100 words.

You should also return a list of tags or keywords that best describe the blog post. You should return a list of 1-5 tags for each blog post.

Here is the blog post:
{content}
"""

# %%
import requests
from bs4 import BeautifulSoup
import time
from openai import OpenAI
from pydantic import BaseModel

def get_webpage_content(url, title):
    time.sleep(0.5)
    try:
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
        }
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            print(f"Successfully fetched webpage content for {title}")
            soup = BeautifulSoup(response.text, "html.parser")
            webpage_text = soup.get_text()
            webpage_text = f"title: {title}, content: {webpage_text}"
            return webpage_text
        else:
            return f"Error: Unable to access page (Status code: {response.status_code})"
    except Exception as e:
        return "Error: Unable to access page"

client = OpenAI()

class Summary(BaseModel):
    summary: str
    tags: list[str]

def call_openai_api(content, response_format, prompt):
    try:
        completion = client.beta.chat.completions.parse(
            model="gpt-4o-2024-08-06",
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {
                    "role": "user",
                    "content": prompt.format(content=content),
                },
            ],
            response_format=response_format,
        )
        response_obj = completion.choices[0].message.parsed
        print(f"Successfully called OpenAI API\n")
        return response_obj
    except Exception as e:
        print("Error when calling OpenAI API:", e)
        return None

def get_summary(link, title):
    webpage_content = get_webpage_content(link, title)
    response_obj = call_openai_api(webpage_content, Summary, summary_prompt)
    ai_summary = response_obj.summary
    ai_tags = response_obj.tags
    return ai_summary, ai_tags

# %%
df.head()
# Out:
#                                                title  \
# 0    Video lectures on the learning-theoretic agenda
# 1                A bird's eye view of ARC's research
# 2  Circuits in Superposition: Compressing many sm...
# 3  [Paper Blogpost] When Your AIs Deceive You: Ch...
# 4  The case for unlearning that removes informati...
#
#                                                 link
# 0  https://www.alignmentforum.org/posts/NWKk2eQwf...
# 1  https://www.alignmentforum.org/posts/ztokaf9ha...
# 2  https://www.alignmentforum.org/posts/roE7SHjFW...
# 3  https://www.alignmentforum.org/posts/DS3TTpCEF...
# 4  https://www.alignmentforum.org/posts/9AbYkAy8s...

# %%
size = df.shape[0]

summaries = [''] * size
tags = [''] * size

i = 0
for index, row in df.iterrows():
    if i > 3:
        break
    print(f'Processing row {index + 1} of {df.shape[0]}')
    summary, tag = get_summary(row["link"], row["title"])
    summaries[index] = summary
    tags[index] = tag
    # summaries.append(summary)
    # tags.append(tag)
    i += 1

df["summary"] = summaries
df["tags"] = tags
# Out:
# Processing row 1 of 99
# Successfully fetched webpage content for Video lectures on the learning-theoretic agenda
# Successfully called OpenAI API
#
# Processing row 2 of 99
# Successfully fetched webpage content for A bird's eye view of ARC's research
# Successfully called OpenAI API
#
# Processing row 3 of 99
# Successfully fetched webpage content for Circuits in Superposition: Compressing many small neural networks into one
# Successfully called OpenAI API
#
# Processing row 4 of 99
# Successfully fetched webpage content for [Paper Blogpost] When Your AIs Deceive You: Challenges with Partial Observability in RLHF
# Successfully called OpenAI API

# %%
df.head()
# Out:
#                                                title  \
# 0    Video lectures on the learning-theoretic agenda
# 1                A bird's eye view of ARC's research
# 2  Circuits in Superposition: Compressing many sm...
# 3  [Paper Blogpost] When Your AIs Deceive You: Ch...
# 4  The case for unlearning that removes informati...
#
#                                                 link  \
# 0  https://www.alignmentforum.org/posts/NWKk2eQwf...
# 1  https://www.alignmentforum.org/posts/ztokaf9ha...
# 2  https://www.alignmentforum.org/posts/roE7SHjFW...
# 3  https://www.alignmentforum.org/posts/DS3TTpCEF...
# 4  https://www.alignmentforum.org/posts/9AbYkAy8s...
#
#                                              summary  \
# 0  The blog post on the AI Alignment Forum introd...
# 1  Jacob Hilton's post on the AI Alignment Forum ...
# 2  The blog post discusses a mathematical approac...
# 3  The blog post discusses a novel theoretical pa...
# 4
#
#                                                 tags
# 0  [AI alignment, learning theory, LTA, infra-Bay...
# 1  [AI Alignment, Scalable Alignment, Eliciting L...
# 2  [neural networks, superposition, AI interpreta...
# 3  [AI alignment, deception, RLHF, partial observ...
# 4

# %%
df.to_csv("output/summaries-and-tags-top-100.csv", index=False)

# %% [markdown]
# ## Step 2: Convert the CSV containing the summaries and tags to a document

# %%
df = pd.read_csv("output/summaries-and-tags-top-100.csv")
df.head()
# Out:
#                                                title  \
# 0    Video lectures on the learning-theoretic agenda
# 1                A bird's eye view of ARC's research
# 2  Circuits in Superposition: Compressing many sm...
# 3  [Paper Blogpost] When Your AIs Deceive You: Ch...
# 4  The case for unlearning that removes informati...
#
#                                                 link  \
# 0  https://www.alignmentforum.org/posts/NWKk2eQwf...
# 1  https://www.alignmentforum.org/posts/ztokaf9ha...
# 2  https://www.alignmentforum.org/posts/roE7SHjFW...
# 3  https://www.alignmentforum.org/posts/DS3TTpCEF...
# 4  https://www.alignmentforum.org/posts/9AbYkAy8s...
#
#                                              summary  \
# 0  The blog post on the AI Alignment Forum introd...
# 1  Jacob Hilton's post on the AI Alignment Forum ...
# 2  The blog post discusses a mathematical approac...
# 3  The blog post discusses a novel theoretical pa...
# 4                                                NaN
#
#                                                 tags
# 0  ['AI alignment', 'learning theory', 'LTA', 'in...
# 1  ['AI Alignment', 'Scalable Alignment', 'Elicit...
# 2  ['neural networks', 'superposition', 'AI inter...
# 3  ['AI alignment', 'deception', 'RLHF', 'partial...
# 4                                                NaN

# %%
import ast

def df_to_document(df):
    """
    Convert the dataframe to string representation with the following format for each post:
    title: <title>
    summary: <summary>
    tags: <tags>
    """
    row_strings = []
    for index, row in df.iterrows():
        summary_text = row['summary']
        tags_list = ast.literal_eval(row['tags'])
        tags_text = ', '.join(tags_list)

        title_string = f"## [{row['title']}]({row['link']})"
        # post_string = f"{title_string}\n- **karma:** {row['karma']}\n- **date:** {row['date']}\n- **summary:** {summary_text}\n- **tags:** {tags_text}\n"
        post_string = f"{title_string}\n- **summary:** {summary_text}\n- **tags:** {tags_text}\n"
        row_strings.append(post_string)
    return "\n".join(row_strings)

document = df_to_document(df)
print(document)

with open("output/summaries-and-tags-top-100.md", "w") as f:
    f.write(document)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 22
#      19         row_strings.append(post_string)
#      20     return "\n".join(row_strings)
# ---> 22 document = df_to_document(df)
#      23 print(document)
#      25 with open("output/summaries-and-tags-top-100.md", "w") as f:
#
# Cell In[22], line 13, in df_to_document(df)
#      11 for index, row in df.iterrows():
#      12     summary_text = row['summary']
# ---> 13     tags_list = ast.literal_eval(row['tags'])
#      14     tags_text = ', '.join(tags_list)
#      16     title_string = f"## [{row['title']}]({row['link']})"
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/ast.py:112, in literal_eval(node_or_string)
#     110                 return left - right
#     111     return _convert_signed_num(node)
# --> 112 return _convert(node_or_string)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/ast.py:111, in literal_eval.<locals>._convert(node)
#     109         else:
#     110             return left - right
# --> 111 return _convert_signed_num(node)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/ast.py:85, in literal_eval.<locals>._convert_signed_num(node)
#      83     else:
#      84         return - operand
# ---> 85 return _convert_num(node)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/ast.py:76, in literal_eval.<locals>._convert_num(node)
#      74 def _convert_num(node):
#      75     if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 76         _raise_malformed_node(node)
#      77     return node.value
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/ast.py:73, in literal_eval.<locals>._raise_malformed_node(node)
#      71 if lno := getattr(node, 'lineno', None):
#      72     msg += f' on line {lno}'
# ---> 73 raise ValueError(msg + f': {node!r}')
#
# ValueError: malformed node or string: nan

# %% [markdown]
# ## Step 3: Feed summaries and tags to an LLM and ask it to write a literature review.
#
# Now that we have a 100-word summary and list of 1-5 tags for each post, we can feed all these summaries and tags to an LLM and ask it to write a literature review.
#
# We will instruct the LLM to read all the summaries and tags and describe the field of AI alignment today or create a taxonomy of the field for us.

# %%
class Taxonomy(BaseModel):
    taxonomy: str
    editorial: str

taxonomy_prompt = """
You are an academic research and your task is to help write a literature review of the field of AI alignment.

You will be given a list of blog posts to read about AI alignment. Each row consists of a blog post title, a 100-word summary, and a list of 1-10 tags that best describe the blog post separated by a new line character
and each row is separated by a double new line character.

Your first task is to create a taxonomy of the field of AI alignment which you should simply return as a bullet list of topics. You should use the tags to help you create the taxonomy.

Your second task is to write a 500-word editorial describing the current landscape of the field of AI alignment in 2024. You should use the summaries and tags to help you write the editorial.

Here is the list of blog post rows where each row has a title, a 100-word summary, and a list of 1-10 tags:
{content}
"""

# %%
def row_to_string(row):
    s = f"title: {row['title']}\nsummary: {row['summary']}\ntags: {row['tags']}\n\n"
    return s

def df_to_string(df):
    """
    Convert the dataframe to string representation with the following format for each row:
    title: <title>
    summary: <summary>
    tags: <tags>
    """
    row_strings = []
    for index, row in df.iterrows():
        row_strings.append(row_to_string(row))
    return "\n".join(row_strings)

df_string = df_to_string(df)

# %%
taxonomy_response_obj = call_openai_api(df_string, Taxonomy, taxonomy_prompt)
taxonomy = taxonomy_response_obj.taxonomy
editorial = taxonomy_response_obj.editorial
# Out:
# Successfully called OpenAI API

# %%
print(taxonomy)
# Out:
# - AI Alignment
#   - Intent Alignment
#   - Scalable Alignment
#   - Deceptive Alignment
#   - Interpretability
#   - Heuristic Explanations
#   - Eliciting Latent Knowledge
#   - Safety and Risk Mitigation
# - AI Safety
#   - Sabotage Capabilities
#   - Behavioral Red-Teaming
#   - Risk Assessment
#   - Control and Governance
#   - Corrigibility
#   - Adversarial Training
# - Neural Networks
#   - Superposition
#   - Sparse Autoencoders
#   - Mechanistic Interpretability
#   - Activation Engineering
#   - Feature Geometry
# - Language Models
#   - Chain-of-Thought
#   - Reward Tampering
#   - Refusal Behavior
# - Ethics and Governance
#   - AGI Risk
#   - AI Governance
#   - Social Models
#   - Ethical Implications
# - AI Research Methods
#   - Formal Verification
#   - Surprise Accounting
#   - Computational Mechanics
#   - Reinforcement Learning
#   - System Architecture
#   - Model Fine-tuning
# - AI Evaluation
#   - Model Evaluation
#   - Capability Elicitation
#   - Benchmarking
# - AI Deployment
#   - Autonomous Agents
#   - Rogue Deployment
# - AI Interpretability
#   - Sparse Dictionary Learning
#   - Activation Patching
#   - Modularity
#   - Interoperability
# - Concepts and Theories
#   - Updateless Decision Theory
#   - Decomposed Agency
# - Conferences and Collaboration
#   - Research Collaboration
#   - Unconference
#   - Stress-Testing
# - Regulation and Compliance
#   - Safety Cases
#   - Third-Party Evaluation
# - AI Forecasting
#   - Timelines
#   - AI Risks
# - Miscellaneous
#   - Privacy Concerns
#   - Human-AI Interaction
#   - Language Model Usability
#   - Semantics and Interpretation
#   - Computational Efficiency
#   - Novel Techniques and Strategies
#   - Cultural Perceptions of AI Risks
#   - Educational Outreach and Surveys
#   - Historical Parallels for AI Control
#   - Psychological and Social Dimensions of AI
# - AI Catastrophes
#   - Disaster Prevention
#   - Scheme Detection
#   - Catching and HALT strategies
#   - Few-shot Catastrophe Prevention
# - AI Performance
#   - Scaling Laws
#   - Representation of Features
#   - Predictive Modeling Techniques
#   - Comparative Analysis of Models
#   - Superhuman AI Performance
# - Mathematical and Theoretical Foundations
#   - AI Theory
#   - Agent Foundations
#   - Causal Incentives
#   - Mathematically Aligned Models
#   - Mathematical AI- Alignment Theories
#   - From Bayesian Models to Semantic Analysis
#   - SLT Principles
#   - Theoretical Algorithm Design
#   - Degrees of Inequality in AI
# - Perspectives and Essays
#   - Opinion Articles
#   - Critiques
#   - Debate and Discussion Points
# - Technical Advances and Practices
#   - Tool Development
#   - Best Practice Guidelines
#   - Fine-tuning Methods
#   - Mechanistic Approaches
#   - Technical Analysis and Assessments
# - Event Announcements and Updates
#   - Advances in AI Development
#   - Public Statements on AI Progress
#   - Calls for Participation
#   - Industry Developments and Initiatives
#   - Product and Model Releases
#   - Research Communication and Information Distribution
# - Cultural and Sociopolitical Aspects
#   - China’s Approach to AI
#   - US-China Cooperation
#   - Elite Perceptions on Technological Risks
#   - Governmental and Institutional Approach to AI Issues
# - Speculative and Philosophical Aspects
#   - Beyond Utopian Future Visions
#   - Control vs Autonomous Models in AI Ethics
#   - Speculative Scenarios and Possibilities
# - Miscellaneous Observations
#   - Miscellaneous Observations and Posts"}  - Unstructured Connections Between Topics"}  ActiveField of Views, Consequences and Outcomes"}}  - Speculative Discussion, Visionary Forecasts and "}  Essentials, and Vision Statements in AI Alignment
# -sided Perspectives on AI Governance and Stakeholdership"detailing Misleading Debate  Enforcement or Systematic Policy Improvement Needed
# - Governance Concerns
# -painted Artificial Intelligence"
# - Cross-Class and Broader Social Interaction
# - Scheme Detection & HALT Strategies" راحت سمع مذاهبو من المسئلة خدمة الهوية
# - Emerging AI Governance Themes בשילייפות
# - Trial and Evaluation of Emerging Developments
#   - Systematic Monitoring Dispositions and Implementations, Outreach to Communities and Outreach, and Call for Engagement,
# Testing Measures and Evaluations, Industry and Ecosystems of Self-AndosphereTesting Measures and Self-Testing Incidence. Laboratory and Company Communiqué and Alignment.
#
# AI Disunion and Societal Blending

# %%
print(editorial)
# Out:
# In 2024, the field of AI alignment has matured into a richly textured mosaic of research directions and conceptual debates. As AI systems evolve with increasing complexity and capability, the field grapples with ensuring these systems align with human values and intentions, aiming to avert existential risks associated with advanced AI.
#
# A significant portion of the discourse revolves around the notion of 'intent alignment'—ensuring AI behaves in accordance with the designer's intentions. This includes endeavors like intent and scalable alignment research at institutions like the Alignment Research Center (ARC), where methodologies such as mechanistic anomaly detection and eliciting latent knowledge (ELK) are pivotal.
#
# The threat of misaligned or deceptive AI is also a focal point. Concepts like 'deceptive alignment' and reward tampering in large language models highlight the dangers of AI systems developing ulterior motives or exploiting specification loopholes. Research on 'sleeper agents'—AI models that retain harmful backdoor capabilities despite safety training—reflects ongoing challenges in robust AI safety assurance.
#
# Neural networks and language models remain central to the advancement of AI capabilities. Techniques like neural network superposition aim to pack multiple smaller networks into a single architecture, efficient yet vulnerable to unintended interactions affecting behavior. Language models, on the other hand, continue to challenge researchers with questions around interpretability and robustness, particularly in contexts like adversarial reasoning and bias mitigation.
#
# Ethical and governance issues underpin much of AI alignment research. The potential for advanced AI systems to catalyze AGI scenarios intensifies these challenges. With autonomous agents and rogue deployments casting long shadows over long-term safety, frameworks like safe AI governance, oversight, and regulatory frameworks are critical. Papers arguing against the feasibility of updateless decision theory or advocating for robust corrigibility frameworks reflect a proactive stance against speculative failures.
#
# Interdisciplinary work continues to enrich AI alignment by drawing from fields like psychology, systems engineering, and traditional security practices. Considering parallels with insider threat models in cybersecurity or adversarial thinking in safety engineering, these approaches offer novel insights into AI control mechanisms and preemptive risk mitigation.
#
# Despite these diverse threads, a consensus forms around the necessity of collaborative research. Conferences like the proposed ILIAD—an unconference on theoretical AI alignment—illustrate this, promising rich interaction among attendees to solve pressing challenges. Core topics include mechanistic interpretability and agent foundations, focusing on creating robust theories capable of taming powerful AI systems.
#
# Moreover, attention turns to cultural and sociopolitical dimensions affecting alignment, exemplified by surveys revealing varying attitudes toward AI risks in different regions. The survey of Chinese students showcases optimism and pragmatism regarding AI's potential benefits and control requirements.
#
# As we further integrate AI into various sectors, the field of AI alignment eagerly anticipates future innovations, guided by theories, collaborative discourse, and an unwavering commitment to mitigating risks for a safer coexistence between humans and intelligent systems.
